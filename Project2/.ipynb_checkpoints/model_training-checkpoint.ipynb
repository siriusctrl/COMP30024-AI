# %%
CELLS = [(q, r) for q in range(-3, +3 + 1) for r in range(-3, +3 + 1) if -q - r in range(-3, +3 + 1)]

# %%
import tensorflow as tf
import numpy as np
from keras import models, layers
from keras.models import load_model
import json
import pickle
import os
from os.path import join
import subprocess
import json
import VanGame.utils as utils
import scipy as sp
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# Using TensorFlow backend.

# %%
sequence = sorted([p for p in CELLS])
sequence
# Out:
# [(-3, 0),
#  (-3, 1),
#  (-3, 2),
#  (-3, 3),
#  (-2, -1),
#  (-2, 0),
#  (-2, 1),
#  (-2, 2),
#  (-2, 3),
#  (-1, -2),
#  (-1, -1),
#  (-1, 0),
#  (-1, 1),
#  (-1, 2),
#  (-1, 3),
#  (0, -3),
#  (0, -2),
#  (0, -1),
#  (0, 0),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (1, -3),
#  (1, -2),
#  (1, -1),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (2, -3),
#  (2, -2),
#  (2, -1),
#  (2, 0),
#  (2, 1),
#  (3, -3),
#  (3, -2),
#  (3, -1),
#  (3, 0)]

# %%
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(100,activation='relu', input_shape=(11,)))
    model.add(layers.Dense(200, activation='relu'))
    model.add(layers.Dense(100, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse')
    return model

# %%
#model = build_model()
# Out:
# WARNING:tensorflow:From /Users/shouyin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def bash_call(c:[str]) -> None:
    res = subprocess.check_output(c)
    ls = []
    for line in res.splitlines():
        line = line.decode('utf-8')
        ls.append(line)
    return ls

# %%
def join_list(l):
    res = ""
    for i in l:
        res += i + "/"
    
    res = res[:-1]
    return res

# %%
def load_logs():
    datapath = join(os.getcwd(),'rec/')
    van_files = bash_call(['ls', datapath])
    for i in range(len(van_files)):
        van_files[i] = 'rec/' + van_files[i]
    
    datapath = join(os.getcwd(),'hardcode_rec/')
    hardcode_file = bash_call(['ls', datapath])
    
    for i in range(len(hardcode_file)):
        hardcode_file[i] = 'hardcode_rec/' + hardcode_file[i]

    return van_files + hardcode_file

# %%
import math

def sigmoid(x):
    return 1/(1+math.exp(-x))

# %%
def PG_log(filename, condition=None, value_check=False):
    
    if (condition != None) and (condition not in filename):
        return False, False
    
    #print(filename)
    states, color = utils.load_l(filename)
    
    train = []
    value = []
    
    for s in states:
        # print(s)
        board = []
        # add board
        for cord in sequence:
            # does not include the board
            break
            board.append(s['board'][cord])
        # color 
        # board.append(color)
        board.append(s['turns'])
        board += s['utility']
        board.append(s['ev'])
        train.append(board)
        value.append(s['rew'])
        
    if value_check:
        print(value)
        
    value.reverse()
    decay = 0.7
    curr_decay = 0.7
    for i in range(1, len(value)):
        value[i] += value[i-1] * curr_decay
        curr_decay *= decay
    
    value.reverse()
    
    if value_check:
        print(value)
    
    post_value = np.array(value)
    
    post_value = np.tanh(post_value)
    
    # normalize the value
    # post_value = (post_value - post_value.mean()) / post_value.std()
    
    if value_check:
        print("\n",post_value)
    
    return train, post_value.tolist()

# %%
# this is only for test, don't run
t,v = PG_log('hardcode_rec/[1win]1556692620.0caobluejiba.txt', value_check=True)
#print(t)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-22a46e065e62> in <module>
# ----> 1 t,v = PG_log('hardcode_rec/[1win]1556692620.0caobluejiba.txt', value_check=True)
#       2 #print(t)
#
# <ipython-input-11-92acdf3ade1d> in PG_log(filename, condition, value_check)
#       5
#       6     #print(filename)
# ----> 7     states, color = utils.load_l(filename)
#       8
#       9     train = []
#
# ~/Desktop/gitKrakenProjects/COMP30024-AI/Project2/VanGame/utils.py in load_l(path)
#     139     colour = t[:t.index("jiba")]
#     140
# --> 141     with open(path, "r") as f:
#     142         data = json.load(f)
#     143         for m in range(len(data)):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hardcode_rec/[1win]1556692620.0caobluejiba.txt'

# %%
# !ls 'hardcode_rec'
# Out:
# '[1win]1556691305.0caoredjiba.txt'    '[1win]1556693327.0caobluejiba.txt'
# '[1win]1556691368.0caogreenjiba.txt'  '[2zzz]1556691289.0caoredjiba.txt'
# '[1win]1556691375.0caogreenjiba.txt'  '[2zzz]1556691294.0caoredjiba.txt'
# '[1win]1556691402.0caogreenjiba.txt'  '[2zzz]1556691314.0caoredjiba.txt'
# '[1win]1556691412.0caogreenjiba.txt'  '[2zzz]1556691319.0caoredjiba.txt'
# '[1win]1556691437.0caogreenjiba.txt'  '[2zzz]1556691329.0caoredjiba.txt'
# '[1win]1556691455.0caogreenjiba.txt'  '[2zzz]1556691349.0caoredjiba.txt'
# '[1win]1556691476.0caoredjiba.txt'    '[2zzz]1556691425.0caogreenjiba.txt'
# '[1win]1556691500.0caoredjiba.txt'    '[2zzz]1556691432.0caogreenjiba.txt'
# '[1win]1556691506.0caoredjiba.txt'    '[2zzz]1556691449.0caogreenjiba.txt'
# '[1win]1556691616.0caoredjiba.txt'    '[2zzz]1556691460.0caogreenjiba.txt'
# '[1win]1556691728.0caoredjiba.txt'    '[2zzz]1556691483.0caoredjiba.txt'
# '[1win]1556691738.0caoredjiba.txt'    '[2zzz]1556691493.0caoredjiba.txt'
# '[1win]1556691745.0caoredjiba.txt'    '[2zzz]1556691538.0caoredjiba.txt'
# '[1win]1556691778.0caoredjiba.txt'    '[2zzz]1556691659.0caoredjiba.txt'
# '[1win]1556691783.0caoredjiba.txt'    '[2zzz]1556691665.0caoredjiba.txt'
# '[1win]1556691787.0caoredjiba.txt'    '[2zzz]1556691703.0caoredjiba.txt'
# '[1win]1556691791.0caoredjiba.txt'    '[2zzz]1556691742.0caoredjiba.txt'
# '[1win]1556691836.0caoredjiba.txt'    '[2zzz]1556691759.0caoredjiba.txt'
# '[1win]1556691852.0caoredjiba.txt'    '[2zzz]1556691763.0caoredjiba.txt'
# '[1win]1556691870.0caoredjiba.txt'    '[2zzz]1556691767.0caoredjiba.txt'
# '[1win]1556691901.0caoredjiba.txt'    '[2zzz]1556691796.0caoredjiba.txt'
# '[1win]1556692011.0caobluejiba.txt'   '[2zzz]1556691844.0caoredjiba.txt'
# '[1win]1556692066.0caobluejiba.txt'   '[2zzz]1556691848.0caoredjiba.txt'
# '[1win]1556692121.0caobluejiba.txt'   '[2zzz]1556692035.0caobluejiba.txt'
# '[1win]1556692152.0caobluejiba.txt'

# %%
def reload_model():
    del model  # deletes the existing model

    # returns a compiled model
    # identical to the previous one
    model = load_model('my_model.h5')

# %%
def save_model():
    model.save('VanGame/my_model.h5')  # creates a HDF5 file 'my_model.h5'
    with open('VanGame/trained_model', 'wb+') as f:
        pickle.dump(model.get_weights(), f)

# %%
def train(epochs, save=True):
    logfs = load_logs()
    train_set = []
    target_set = []
    
    for logf in logfs:
        train, value = PG_log(logf)
        if train:
            # print(train)
            # print(len(train), len(value))
            #print(train[-1])
            train_set += train
            # the target shouldnt be calculate like this, should use bootstrapping
            target_set += value

    model.fit(np.array(train_set), target_set, epochs=epochs, batch_size=1)
    
    if save:
        print("saved")
        save_model()

# %%
model.predict(np.array([[-1]*11]))
# Out:
# array([[0.15931465]], dtype=float32)

# %%
# don't run this, or ask me
#save_model()
#del model

#try:
#    model = load_model('VanGame/my_model.h5')
#except:
#    print("none model found")
#    model = build_model()
# Out:
# WARNING:tensorflow:From /Users/shouyin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
def full_train_cycle(n, epochs=2):
    for i in range(n):
        # !python3 -m referee VanGame VanGame VanGame -l logtry -v 0
    if ( len(bash_call(['ls', 'rec'])) + len(bash_call(['ls', 'hardcode_rec'])) ) > 0:
        train(epochs=epochs)
        # !rm -v ./rec/*
        # !rm -v ./hardcode_rec/*

# %%
for i in range(500):
    print("********** starting round", i, "**********")
    full_train_cycle(1, epochs=1)
# Out:
# ********** starting round 0 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/1
# 749/749 [==============================] - 2s 3ms/step - loss: 0.0042
# saved
# removed './rec/[1win]1556704319.0caoredjiba.txt'
# removed './rec/[1win]1556704333.0caoredjiba.txt'
# removed './rec/[2zzz]1556704319.0caobluejiba.txt'
# removed './rec/[2zzz]1556704319.0caogreenjiba.txt'
# removed './rec/[2zzz]1556704333.0caobluejiba.txt'
# removed './rec/[2zzz]1556704333.0caogreenjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 1 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 293/293 [==============================] - 1s 3ms/step - loss: 0.0036
# saved
# removed './rec/[1win]1556704339.0caogreenjiba.txt'
# removed './rec/[2zzz]1556704339.0caobluejiba.txt'
# removed './rec/[2zzz]1556704339.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 2 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/1
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0085
# saved
# removed './rec/[1win]1556704344.0caoredjiba.txt'
# removed './rec/[2zzz]1556704344.0caobluejiba.txt'
# removed './rec/[2zzz]1556704344.0caogreenjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 3 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 266/266 [==============================] - 1s 3ms/step - loss: 0.0071
# saved
# removed './rec/[1win]1556704349.0caogreenjiba.txt'
# removed './rec/[2zzz]1556704349.0caobluejiba.txt'
# removed './rec/[2zzz]1556704349.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 4 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/1
# 471/471 [==============================] - 1s 3ms/step - loss: 0.0039
# saved
# removed './rec/[1win]1556704357.0caobluejiba.txt'
# removed './rec/[2zzz]1556704357.0caogreenjiba.txt'
# removed './rec/[2zzz]1556704357.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 5 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 515/515 [==============================] - 2s 3ms/step - loss: 0.0030
# saved
# removed './rec/[1win]1556704366.0caogreenjiba.txt'
# removed './rec/[2zzz]1556704366.0caobluejiba.txt'
# removed './rec/[2zzz]1556704366.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 6 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 692/692 [==============================] - 2s 3ms/step - loss: 0.0027
# saved
# removed './rec/[1win]1556704379.0caogreenjiba.txt'
# removed './rec/[2zzz]1556
**********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/1
# 549/549 [==============================] - 2s 3ms/step - loss: 0.0015
# saved
# removed './rec/[1win]1556706284.0caobluejiba.txt'
# removed './rec/[2zzz]1556706284.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706284.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 256 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 320/320 [==============================] - 1s 3ms/step - loss: 0.0049
# saved
# removed './rec/[1win]1556706291.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706291.0caobluejiba.txt'
# removed './rec/[2zzz]1556706291.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 257 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/1
# 603/603 [==============================] - 2s 3ms/step - loss: 0.0030
# saved
# removed './rec/[1win]1556706301.0caobluejiba.txt'
# removed './rec/[2zzz]1556706301.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706301.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 258 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/1
# 466/466 [==============================] - 1s 3ms/step - loss: 0.0040
# saved
# removed './rec/[1win]1556706310.0caoredjiba.txt'
# removed './rec/[2zzz]1556706310.0caobluejiba.txt'
# removed './rec/[2zzz]1556706310.0caogreenjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 259 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 419/419 [==============================] - 1s 3ms/step - loss: 0.0037
# saved
# removed './rec/[1win]1556706318.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706318.0caobluejiba.txt'
# removed './rec/[2zzz]1556706318.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 260 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 212/212 [==============================] - 1s 3ms/step - loss: 0.0114
# saved
# removed './rec/[1win]1556706323.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706323.0caobluejiba.txt'
# removed './rec/[2zzz]1556706323.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 261 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/1
# 446/446 [==============================] - 1s 3ms/step - loss: 0.0028
# saved
# removed './rec/[1win]1556706330.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706330.0caobluejiba.txt'
# removed './rec/[2zzz]1556706330.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 262 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/1
# 351/351 [==============================] - 1s 3ms/step - loss: 0.0050
# saved
# removed './rec/[1win]1556706337.0caobluejiba.txt'
# removed './rec/[2zzz]1556706337.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706337.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 263 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * draw detected: maximum number of turns reached.
# ********** starting round 264 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/1
# 372/372 [==============================] - 1s 3ms/step - loss: 0.0036
# saved
# removed './rec/[1win]1556706356.0caobluejiba.txt'
# removed './rec/[2zzz]1556706356.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706356.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 265 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/1
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0053
# saved
# removed './rec/[1win]1556706363.0caobluejiba.txt'
# removed './rec/[2zzz]1556706363.0caogreenjiba.txt'
# removed './rec/[2zzz]1556706363.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 266 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/1
# 598/598 [==============================] - 2s 3ms/step - loss: 0.0017
# saved
# removed './rec/[1win]1556706372.0caoredjiba.txt'
# removed './rec/[2zzz]1556706372.0caobluejiba.txt'
# removed './rec/[2zzz]1556706372.0caogreenjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 267 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# ^C
#
# ********** starting round 268 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# ^C
#
# ********** starting round 269 **********
# ^C
# Exception ignored in: <function _get_module_lock.<locals>.cb at 0x113cd9840>
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 176, in cb
# KeyboardInterrupt
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# ********** starting round 270 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-a7dc8d3474db> in <module>
#       1 for i in range(500):
#       2     print("********** starting round", i, "**********")
# ----> 3     full_train_cycle(1, epochs=1)
#
# <ipython-input-26-41063bd78e80> in full_train_cycle(n, epochs)
#       2     for i in range(n):
#       3         get_ipython().system('python3 -m referee VanGame VanGame VanGame -l logtry -v 0')
# ----> 4     if ( len(bash_call(['ls', 'rec'])) + len(bash_call(['ls', 'hardcode_rec'])) ) > 0:
#       5         train(epochs=epochs)
#       6         get_ipython().system('rm -v ./rec/*')
#
# <ipython-input-8-a04a5f66ab30> in bash_call(c)
#       1 def bash_call(c:[str]) -> None:
# ----> 2     res = subprocess.check_output(c)
#       3     ls = []
#       4     for line in res.splitlines():
#       5         line = line.decode('utf-8')
#
# ~/anaconda3/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     387
#     388     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 389                **kwargs).stdout
#     390
#     391
#
# ~/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     464         kwargs['stderr'] = PIPE
#     465
# --> 466     with Popen(*popenargs, **kwargs) as process:
#     467         try:
#     468             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     767                                 c2pread, c2pwrite,
#     768                                 errread, errwrite,
# --> 769                                 restore_signals, start_new_session)
#     770         except:
#     771             # Cleanup if the child failed starting.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1468                 errpipe_data = bytearray()
#    1469                 while True:
# -> 1470                     part = os.read(errpipe_read, 50000)
#    1471                     errpipe_data += part
#    1472                     if not part or len(errpipe_data) > 50000:
#
# KeyboardInterrupt:

# %%
for i in range(2):
    print("********** starting round", i, "**********")
    full_train_cycle(2, epochs=1)
# Out:
# ********** starting round 0 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * draw detected: maximum number of turns reached.
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# 76 76
# 173 173
# 75 75
# 76 76
# 173 173
# 173 173
# Epoch 1/1
# 746/746 [==============================] - 2s 3ms/step - loss: 0.0049
# saved
# removed './rec/[1win]1556703582.0caogreenjiba.txt'
# removed './rec/[1win]1556703634.0caobluejiba.txt'
# removed './rec/[2zzz]1556703582.0caobluejiba.txt'
# removed './rec/[2zzz]1556703582.0caoredjiba.txt'
# removed './rec/[2zzz]1556703634.0caogreenjiba.txt'
# removed './rec/[2zzz]1556703634.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory
# ********** starting round 1 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * draw detected: maximum number of turns reached.
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# 161 161
# 161 161
# 161 161
# Epoch 1/1
# 483/483 [==============================] - 1s 3ms/step - loss: 0.0017
# saved
# removed './rec/[1win]1556703651.0caobluejiba.txt'
# removed './rec/[2zzz]1556703651.0caogreenjiba.txt'
# removed './rec/[2zzz]1556703651.0caoredjiba.txt'
# rm: cannot remove './hardcode_rec/*': No such file or directory

# %% [markdown]
# # CNN attamp

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
#create model
md = Sequential()
#add model layers
md.add(Conv2D(1, kernel_size=3, activation='relu', input_shape=(28,28,1), use_bias=False))
#md.add(layers.MaxPooling2D(2,2))
#md.add(Conv2D(64, kernel_size=3, activation='relu', use_bias=False))
#md.add(layers.MaxPooling2D(2,2))
#md.add(Conv2D(64, kernel_size=3, activation='relu', use_bias=False))
md.add(Flatten())
md.compile(optimizer='adam', loss='mse')

# %%
for i in md.get_weights():
    print(i.shape)

# %%
md.summary()

# %%
md.predict(np.array([[[[1]*28]*28]]).reshape(1,28,28,1))

# %%
asdf = md.get_weights()[0].reshape(3,3)

# %%
wds = md.get_weights()

# %%
convp = wds[0]

# %%
convp.shape

# %%
c = convp.reshape(1, 3, 3, 1)

# %%
d = c[0].reshape(3,3)

# %%
import scipy.signal as signal

# %%
a = np.array([[[1]*28]*28]).reshape(28,28)

# %%
e = signal.convolve2d(a, asdf, mode='valid')

# %%
e

# %%
signal.convolve(e, )
