# %%
CELLS = [(q, r) for q in range(-3, +3 + 1) for r in range(-3, +3 + 1) if -q - r in range(-3, +3 + 1)]

# %%
import tensorflow as tf
import numpy as np
from keras import models, layers
from keras.models import load_model
import json
import pickle
import os
from os.path import join
import subprocess
import json
import VanGame.utils as utils
import scipy as sp
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# Using TensorFlow backend.

# %%
sequence = sorted([p for p in CELLS])
sequence
# Out:
# [(-3, 0),
#  (-3, 1),
#  (-3, 2),
#  (-3, 3),
#  (-2, -1),
#  (-2, 0),
#  (-2, 1),
#  (-2, 2),
#  (-2, 3),
#  (-1, -2),
#  (-1, -1),
#  (-1, 0),
#  (-1, 1),
#  (-1, 2),
#  (-1, 3),
#  (0, -3),
#  (0, -2),
#  (0, -1),
#  (0, 0),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (1, -3),
#  (1, -2),
#  (1, -1),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (2, -3),
#  (2, -2),
#  (2, -1),
#  (2, 0),
#  (2, 1),
#  (3, -3),
#  (3, -2),
#  (3, -1),
#  (3, 0)]

# %%
a = np.array([[1]*39])
b = [500]

# %%
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(1,activation='relu', input_shape=(10,)))
    model.add(layers.Dense(50, activation='relu'))
    model.add(layers.Dense(25, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
model = build_model()

# %%
try:
    model = load_model('VanGame/my_model.h5')
except:
    print("none model found")
    model = build_model()

# %%
def bash_call(c:[str]) -> None:
    res = subprocess.check_output(c)
    ls = []
    for line in res.splitlines():
        line = line.decode('utf-8')
        ls.append(line)
    return ls

# %%
def join_list(l):
    res = ""
    for i in l:
        res += i + "/"
    
    res = res[:-1]
    return res

# %%
def load_logs():
    datapath = join(os.getcwd(),'rec/')
    files = bash_call(['ls', datapath])
    return files

# %%
sigmoid = lambda x: 1 / (1 + np.exp(-x))

# %%
def PG_log(filename, condition=None, value_check=False):
    
    if (condition != None) and (condition not in filename):
        return False, False
    
    #print(filename)
    states, color = utils.load_l('rec/'+filename)
    
    train = []
    value = []
    
    for s in states:
        # print(s)
        board = []
        # add board
        for cord in sequence:
            # does not include the board
            break
            board.append(s['board'][cord])
        # color 
        # board.append(color)
        # utility = [heuristic diff, my pieces difference, danger pieces]
        board.append(s['turns'])
        board += s['utility']
        train.append(board)
        value.append(s['rew'])
        
    if value_check:
        print(value)
        
    value.reverse()
    decay = 0.7
    curr_decay = 0.7
    for i in range(1, len(value)):
        value[i] += value[i-1] * curr_decay
        curr_decay *= decay
    
    value.reverse()
    
    if value_check:
        print(value)
    
    post_value = np.array(value)
    
    post_value = np.tanh(post_value)
    
    # normalize the value
    # post_value = (post_value - post_value.mean()) / post_value.std()
    
    if value_check:
        print("\n",post_value)
    
    return post_train.to_list(), value

# %%
t,v = PG_log('[2zzz]1556674891.0caoredjiba.txt', value_check=True)
#print(t)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-e623dda50bb8> in <module>
# ----> 1 t,v = PG_log('[2zzz]1556674891.0caoredjiba.txt', value_check=True)
#       2 #print(t)
#
# <ipython-input-43-3348158b4af8> in PG_log(filename, condition, value_check)
#       5
#       6     #print(filename)
# ----> 7     states, color = utils.load_l('rec/'+filename)
#       8
#       9     train = []
#
# ~/Documents/COMP30024-AI/Project2/VanGame/utils.py in load_l(path)
#     139     colour = t[:t.index("jiba")]
#     140
# --> 141     with open(path, "r") as f:
#     142         data = json.load(f)
#     143         for m in range(len(data)):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rec/[2zzz]1556674891.0caoredjiba.txt'

# %%
# !ls rec

# %%
def reload_model():
    del model  # deletes the existing model

    # returns a compiled model
    # identical to the previous one
    model = load_model('my_model.h5')

# %%
def save_model():
    model.save('VanGame/my_model.h5')  # creates a HDF5 file 'my_model.h5'
    with open('VanGame/trained_model', 'wb+') as f:
        pickle.dump(model.get_weights(), f)

# %%
def train(epochs, save=True):
    logfs = load_logs()
    train_set = []
    target_set = []
    
    for logf in logfs:
        train, value = PG_log(logf)
        if train:
            #print(len(train), len(value))
            #print(train[-1])
            train_set += train
            # the target shouldnt be calculate like this, should use bootstrapping
            target_set += value

    model.fit(np.array(train_set), target_set, epochs=epochs, batch_size=1)
    if save:
        print("saved")
        save_model()

# %%
train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2da0ffaf5447> in <module>
# ----> 1 train()
#
# TypeError: train() missing 1 required positional argument: 'epochs'

# %%
save_model()

# %%
del model

# %%
model.predict(np.array([[1]*10,[0.5]*10]))
# Out:
# array([[0.04614913],
#        [0.02307456]], dtype=float32)

# %%
def full_train_cycle(n, epochs=2):
    for i in range(n):
        # !python3 -m referee VanGame HardCode HardCode -l logtry -v 0
    if (len(bash_call(['ls', 'rec']))) > 0:
        train(epochs=epochs)
        # !rm -v ./rec/*

# %%
for i in range(50):
    print("********** starting round", i, "**********")
    full_train_cycle(1, epochs=2)
# Out:
# ********** starting round 0 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 1 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 2 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 3 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 4 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 5 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 6 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 7 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 8 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 9 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 10 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 11 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 12 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 13 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
# ...
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 72, in _load_player_class
#     module = importlib.import_module(package_name)
#   File "/anaconda3/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/__init__.py", line 1, in <module>
#     from VanGame.player import Player as Player
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 1, in <module>
#     import VanGame.utils as utils
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 1, in <module>
#     import numpy as np
#   File "/anaconda3/lib/python3.6/site-packages/numpy/__init__.py", line 142, in <module>
#     from . import core
#   File "/anaconda3/lib/python3.6/site-packages/numpy/core/__init__.py", line 71, in <module>
#     raise ImportError(msg)
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the multiarray numpy extension module failed.  Most
# likely you are trying to import a failed build of numpy.
# Here is how to proceed:
# - If you're working with a numpy git repository, try `git clean -xdf`
#   (removes all files not under version control) and rebuild numpy.
# - If you are simply trying to use the numpy version that you have installed:
#   your installation is broken - please reinstall numpy.
# - If you have already reinstalled and that did not fix the problem, then:
#   1. Check that you are using the Python you expect (you're using /anaconda3/bin/python3),
#      and that you have no directories in your PATH or PYTHONPATH that can
#      interfere with the Python and numpy versions you're trying to use.
#   2. If (1) looks fine, you can open a new issue at
#      https://github.com/numpy/numpy/issues.  Please include details on:
#      - how you installed Python
#      - how you installed numpy
#      - your operating system
#      - whether or not you have multiple versions of Python installed
#      - if you built from source, your compiler versions and ideally a build log
#
#      Note: this error has many possible causes, so please don't comment on
#      an existing issue about this - open a new one instead.
#
# Original error was: PyCapsule_Import could not import module "datetime"
#
# ********** starting round 44 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 45 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 46 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  4  |  3  |  2  |  1  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  5  |  4  |  3  |  2  |  1  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  6  |  5  |  4  |  3  |  2  |  1  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  7  |  6  |  5  |  4  |  3  |  2  |  1  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  7  |  6  |  5  |  4  |  3  |  2  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  7  |  6  |  5  |  4  |  3  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  7  |  6  |  5  |  4  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  7  |  7  |  7  |  7  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  6  |  6  |  6  |  6  |  6  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  5  |  5  |  5  |  5  |  5  |  5  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  4  |  4  |  4  |  4  |  4  |  4  |  4  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  3  |  3  |  3  |  3  |  3  |  3  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  2  |  2  |  2  |  2  |  2  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  1  |  1  |  1  |  1  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# #
#     #           .-'-._.-'-._.-'-._.-'-.
#     #          |  1  |  2  |  3  |  4  |
#     #        .-'-._.-'-._.-'-._.-'-._.-'-.
#     #       |  1  |  2  |  3  |  4  |  5  |
#     #     .-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     #    |  1  |  2  |  3  |  4  |  5  |  6  |
#     #  .-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-.
#     # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# /Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py:160: RuntimeWarning: invalid value encountered in true_divide
#   ops = (ops - ops.mean()) / ops.std()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 102, in <module>
#     main()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 36, in main
#     play([p_R, p_G, p_B], options, out)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/__main__.py", line 79, in play
#     action = curr_player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/referee/player.py", line 48, in action
#     action = self.player.action()
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/player.py", line 69, in action
#     return self.strategy.get_possible_moves(self.current_board, self.colour, self.colour_p, self.goal, self.colour_exit)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/strategy.py", line 117, in get_possible_moves
#     ie = utils.chose(all_score)
#   File "/Users/xinyaoniu/Documents/COMP30024-AI/Project2/VanGame/utils.py", line 166, in chose
#     return np.random.choice(len(options), 1, p=prob)[0]
#   File "mtrand.pyx", line 1144, in mtrand.RandomState.choice
# ValueError: probabilities contain NaN
# ********** starting round 47 **********
# ^C
#    # |  1  |  2  |  3  |  4  |  5  |  6  |  7  |
#     # '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #    |  2  |  3  |  4  |  5  |  6  |  7  |
#     #    '-._.-'-._.-'-._.-'-._.-'-._.-'-._.-'
#     #       |  3  |  4  |  5  |  6  |  7  |
#     #       '-._.-'-._.-'-._.-'-._.-'-._.-'
#     #          |  4  |  5  |  6  |  7  |
#     #          '-._.-'-._.-'-._.-'-._.-'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-ee0dd3fb6f88> in <module>
#       1 for i in range(50):
#       2     print("********** starting round", i, "**********")
# ----> 3     full_train_cycle(1, epochs=2)
#
# <ipython-input-58-90fd413a7853> in full_train_cycle(n, epochs)
#       2     for i in range(n):
#       3         get_ipython().system('python3 -m referee VanGame HardCode HardCode -l logtry -v 0')
# ----> 4     if (len(bash_call(['ls', 'rec']))) > 0:
#       5         train(epochs=epochs)
#       6         get_ipython().system('rm -v ./rec/*')
#
# <ipython-input-12-a04a5f66ab30> in bash_call(c)
#       1 def bash_call(c:[str]) -> None:
# ----> 2     res = subprocess.check_output(c)
#       3     ls = []
#       4     for line in res.splitlines():
#       5         line = line.decode('utf-8')
#
# /anaconda3/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     354
#     355     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 356                **kwargs).stdout
#     357
#     358
#
# /anaconda3/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     423     with Popen(*popenargs, **kwargs) as process:
#     424         try:
# --> 425             stdout, stderr = process.communicate(input, timeout=timeout)
#     426         except TimeoutExpired:
#     427             process.kill()
#
# /anaconda3/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     848                 self._stdin_write(input)
#     849             elif self.stdout:
# --> 850                 stdout = self.stdout.read()
#     851                 self.stdout.close()
#     852             elif self.stderr:
#
# KeyboardInterrupt:

# %%
for i in range(5000):
    print("********** starting round", i, "**********")
    full_train_cycle(1, epochs=2)
# Out:
# ********** starting round 0 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/2
# 27/27 [==============================] - 0s 2ms/step - loss: 14786.4777
# Epoch 2/2
# 27/27 [==============================] - 0s 2ms/step - loss: 14591.4403
# saved
# removed './rec/[2zzz]1556638329.0caoredjiba.txt'
# ********** starting round 1 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/2
# 44/44 [==============================] - 0s 2ms/step - loss: 4988.8970
# Epoch 2/2
# 44/44 [==============================] - 0s 2ms/step - loss: 4778.8187
# saved
# removed './rec/[1win]1556638331.0caoredjiba.txt'
# ********** starting round 2 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/2
# 62/62 [==============================] - 0s 2ms/step - loss: 2443.5297
# Epoch 2/2
# 62/62 [==============================] - 0s 2ms/step - loss: 2412.1614
# saved
# removed './rec/[1win]1556638334.0caoredjiba.txt'
# ********** starting round 3 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/2
# 74/74 [==============================] - 0s 2ms/step - loss: 2383.0561
# Epoch 2/2
# 74/74 [==============================] - 0s 2ms/step - loss: 2346.5550: 0s - loss: 2681.65
# saved
# removed './rec/[1win]1556638338.0caoredjiba.txt'
# ********** starting round 4 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 32/32 [==============================] - 0s 2ms/step - loss: 6790.6589
# Epoch 2/2
# 32/32 [==============================] - 0s 2ms/step - loss: 6038.6205
# saved
# removed './rec/[2zzz]1556638339.0caoredjiba.txt'
# ********** starting round 5 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/2
# 22/22 [==============================] - 0s 2ms/step - loss: 10996.3197
# Epoch 2/2
# 22/22 [==============================] - 0s 2ms/step - loss: 9425.2936
# saved
# removed './rec/[2zzz]1556638341.0caoredjiba.txt'
# ********** starting round 6 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/2
# 68/68 [==============================] - 0s 2ms/step - loss: 2991.1777
# Epoch 2/2
# 68/68 [==============================] - 0s 2ms/step - loss: 2948.8441
# saved
# removed './rec/[1win]1556638344.0caoredjiba.txt'
# ********** starting round 7 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Red
# Epoch 1/2
# 68/68 [==============================] - 0s 1ms/step - loss: 3129.0246
# Epoch 2/2
# 68/68 [==============================] - 0s 1ms/step - loss: 3100.9716
# saved
# removed './rec/[1win]1556638348.0caoredjiba.txt'
# ********** starting round 8 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 31/31 [==============================] - 0s 2ms/step - loss: 7492.5242
# Epoch 2/2
# 31/31 [==============================] - 0s 1ms/step - loss: 4802.8384
# saved
# removed './rec/[2zzz]1556638350.0caoredjiba.txt'
# ********** starting round 9 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
#
**********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 26/26 [==============================] - 0s 5ms/step - loss: 7709.3364
# Epoch 2/2
# 26/26 [==============================] - 0s 5ms/step - loss: 2630.4584
# saved
# removed './rec/[2zzz]1556650551.0caoredjiba.txt'
# ********** starting round 4993 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 42/42 [==============================] - 0s 5ms/step - loss: 5536.0948
# Epoch 2/2
# 42/42 [==============================] - 0s 5ms/step - loss: 5188.9644
# saved
# removed './rec/[2zzz]1556650557.0caoredjiba.txt'
# ********** starting round 4994 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/2
# 23/23 [==============================] - 0s 6ms/step - loss: 10431.4993
# Epoch 2/2
# 23/23 [==============================] - 0s 5ms/step - loss: 9211.3038
# saved
# removed './rec/[2zzz]1556650561.0caoredjiba.txt'
# ********** starting round 4995 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 29/29 [==============================] - 0s 5ms/step - loss: 1732.3887
# Epoch 2/2
# 29/29 [==============================] - 0s 5ms/step - loss: 1143.3130
# saved
# removed './rec/[2zzz]1556650566.0caoredjiba.txt'
# ********** starting round 4996 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 38/38 [==============================] - 0s 5ms/step - loss: 4989.8641
# Epoch 2/2
# 38/38 [==============================] - 0s 5ms/step - loss: 4012.6235
# saved
# removed './rec/[2zzz]1556650572.0caoredjiba.txt'
# ********** starting round 4997 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 25/25 [==============================] - 0s 6ms/step - loss: 4833.2166
# Epoch 2/2
# 25/25 [==============================] - 0s 5ms/step - loss: 3415.1530
# saved
# removed './rec/[2zzz]1556650576.0caoredjiba.txt'
# ********** starting round 4998 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Blue
# Epoch 1/2
# 25/25 [==============================] - 0s 6ms/step - loss: 4933.8491
# Epoch 2/2
# 25/25 [==============================] - 0s 5ms/step - loss: 3639.4980
# saved
# removed './rec/[2zzz]1556650581.0caoredjiba.txt'
# ********** starting round 4999 **********
# * NOTE: unable to measure memory usage on this platform (try dimefox)
# * winner: Green
# Epoch 1/2
# 24/24 [==============================] - 0s 6ms/step - loss: 684.1761
# Epoch 2/2
# 24/24 [==============================] - 0s 5ms/step - loss: 371.3060
# saved
# removed './rec/[2zzz]1556650585.0caoredjiba.txt'

# %% [markdown]
# # CNN attamp

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
#create model
md = Sequential()
#add model layers
md.add(Conv2D(1, kernel_size=3, activation='relu', input_shape=(28,28,1), use_bias=False))
#md.add(layers.MaxPooling2D(2,2))
#md.add(Conv2D(64, kernel_size=3, activation='relu', use_bias=False))
#md.add(layers.MaxPooling2D(2,2))
#md.add(Conv2D(64, kernel_size=3, activation='relu', use_bias=False))
md.add(Flatten())
md.compile(optimizer='adam', loss='mse')

# %%
for i in md.get_weights():
    print(i.shape)

# %%
md.summary()

# %%
md.predict(np.array([[[[1]*28]*28]]).reshape(1,28,28,1))

# %%
asdf = md.get_weights()[0].reshape(3,3)

# %%
wds = md.get_weights()

# %%
convp = wds[0]

# %%
convp.shape

# %%
c = convp.reshape(1, 3, 3, 1)

# %%
d = c[0].reshape(3,3)

# %%
import scipy.signal as signal

# %%
a = np.array([[[1]*28]*28]).reshape(28,28)

# %%
e = signal.convolve2d(a, asdf, mode='valid')

# %%
e

# %%
signal.convolve(e, )
